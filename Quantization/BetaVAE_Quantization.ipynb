# %%
#!git clone https://github.com/elina22-hub/11785_SceneDetection_Quantization.git

# %%
#!pip install onnxruntime

# %%
# copy data to 11785 directory
#%cp unique-142p.zip 11785_SceneDetection_Quantization/

# %%
# copy scence chagne.csv to 11785 directory
#%cp scene-change.csv 11785_SceneDetection_Quantization/
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'

# %%
# set current path to github model path
# %cd ./11785_SceneDetection_Quantization
# Out:
# /home/ubuntu/11785_SceneDetection_Quantization

# %%
#!unzip \*.zip

# %%
# %pwd
# Out:
# '/home/ubuntu/11785_SceneDetection_Quantization'

# %%
# packages for Quantization
import os
import yaml
import onnx
import onnx.numpy_helper
import onnxruntime
import onnxruntime.quantization

# packages for loading the model
from model.beta_vae import *
import torch.utils.data 
from torchvision import datasets, transforms
import pdb
import pandas as pd
import torch.nn.functional as F
import torch
import numpy as np
from scene_detection import *
import torchvision.utils as vutils
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import shutil
import warnings

warnings.filterwarnings("ignore")

cuda = torch.cuda.is_available()
NUM_WORKERS = 4 if cuda else 0
DEVICE = torch.device("cuda" if cuda else "cpu")
BATCH_SIZE = 64
IMG_SIZE = 64

print(torch.__version__)
print(cuda)
print(NUM_WORKERS)
print(DEVICE)
# Out:
# 1.8.1+cu111
# False
# 0
# cpu

# %%
# model hyperparameters (beta = 2)
with open("config.yaml", "r") as file:
    config = yaml.safe_load(file)

# %%
config
# Out:
# {'model_params': {'name': 'BetaVAE',
#   'beta': 2,
#   'in_channels': 3,
#   'latent_dim': 10,
#   'loss_type': 'H',
#   'max_capacity': 25,
#   'Capacity_max_iter': 10000,
#   'image_height': 64,
#   'image_width': 64,
#   'hidden_dims': [32, 64, 128, 256, 512]},
#  'exp_params': {'img_size': 64,
#   'train_data_dir': './data_train',
#   'val_data_dir': './data_val',
#   'model_save_dir': './best_model',
#   'batch_size': 256,
#   'learning_rate': 0.002,
#   'weight_decay': 0.0,
#   'scheduler_gamma': 0.6,
#   'max_epochs': 250,
#   'manual_seed': 1265,
#   'log_save_dir': './logs',
#   'log_save_name': 'BetaVAE',
#   'pic_save_dir': './scene_divergence_graph'}}

# %%
# load model
model = BetaVAE(**config['model_params'])
model_name = "Model_baseline"
model_path = "./best_model/" + model_name
checkpoint = torch.load(model_path, map_location="cpu")
model.load_state_dict(checkpoint['model_state_dict'])
# make sure setting the model to eval mode before exporting to ONNX
model.eval()
# Out:
# BetaVAE(
#   (encoder): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): ReLU()
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): ReLU()
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): ReLU()
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): ReLU()
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): ReLU()
#     )
#   )
#   (fc_mu): Linear(in_features=2048, out_features=10, bias=True)
#   (fc_var): Linear(in_features=2048, out_features=10, bias=True)
#   (decoder_input): Linear(in_features=10, out_features=2048, bias=True)
#   (decoder): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): ReLU()
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): ReLU()
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): ReLU()
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): ReLU()
#     )
#   )
#   (final_layer): Sequential(
#     (0): ConvTranspose2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): Sigmoid()
#   )
# )

# %% [markdown]
# ### Data Processing (Run Only Once Unless Terminal Crash)
#
# Notice: Unique images index is not continuous. Also, .DS_Store is in the imagefile, remove it

# %%
# %pwd
# Out:
# '/home/ubuntu/11785_SceneDetection_Quantization'

# %%
# pick the validation set from unique 142p dataset
imagefile = os.listdir("unique-142p")
imageset = set(imagefile)
old_path = "./unique-142p"
new_path = "./unique-142p-valid/142p-image/"
data_dir = "./unique-142p-valid/"
new_data_dir = "./unique-142p-valid/142p-image/"

# %%
# pick validation images
def get_valid_image_list(imagefile):
    """
    input: imagefile -> the unique-142p file
    return: valid_image_list -> image name list for validation
    """
    valid_image_list = []
    st_idx = 1
    ed_idx = 25947
    for image in imagefile:
        if image != ".DS_Store":
            idx = int(image[6:12])
            if st_idx <= idx <= ed_idx:
                valid_image_list.append(image)
    return valid_image_list

# %%
# create file and put it under another file name
def copy_valid_image(valid_image_list, old_path, new_path):
    # determine whether new path exists
    if not os.path.exists(new_path):
        os.makedirs(new_path)
    for valid_image in valid_image_list:
        shutil.copyfile(os.path.join(old_path, valid_image), os.path.join(new_path, valid_image))

# %%
# get validation image list and put it under the corresponding directory
valid_image_list = get_valid_image_list(imagefile)
copy_valid_image(valid_image_list, old_path, new_path)

# %%
# create subfolder for each images in the folder, with name of the subfolder being the int(image[6:12]) name
def create_imagefolder(valid_image_list, image_path):
    for image in os.listdir(image_path):
        os.makedirs(os.path.join(image_path, "folder_"+image))
    # put each image into the subfolder
    for valid_image in valid_image_list:
        shutil.move(os.path.join(image_path, valid_image), os.path.join(image_path, "folder_"+valid_image))

# %%
# create subfolder for each images in the folder, with name of the subfolder being the int(image[6:12]) name
create_imagefolder(valid_image_list, new_path)

# %%
# %cd unique-142p-valid/142p-image/
# Out:
# /home/ubuntu/11785_SceneDetection_Quantization/unique-142p-valid/142p-image

# %%
# %ls
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# folder_frame_000001.png/  folder_frame_006411.png/  folder_frame_016038.png/
# folder_frame_000012.png/  folder_frame_006412.png/  folder_frame_016039.png/
# folder_frame_000015.png/  folder_frame_006413.png/  folder_frame_016040.png/
# folder_frame_000016.png/  folder_frame_006414.png/  folder_frame_016041.png/
# folder_frame_000017.png/  folder_frame_006415.png/  folder_frame_016042.png/
# folder_frame_000018.png/  folder_frame_006416.png/  folder_frame_016043.png/
# folder_frame_000020.png/  folder_frame_006417.png/  folder_frame_016044.png/
# folder_frame_000021.png/  folder_frame_006418.png/  folder_frame_016045.png/
# folder_frame_000022.png/  folder_frame_006420.png/  folder_frame_016046.png/
# folder_frame_000023.png/  folder_frame_006424.png/  folder_frame_016047.png/
# folder_frame_000024.png/  folder_frame_006427.png/  folder_frame_016048.png/
# folder_frame_000025.png/  folder_frame_006429.png/  folder_frame_016049.png/
# folder_frame_000026.png/  folder_frame_006432.png/  folder_frame_016050.png/
# folder_frame_000027.png/  folder_frame_006435.png/  folder_frame_016051.png/
# folder_frame_000028.png/  folder_frame_006438.png/  folder_frame_016052.png/
# folder_frame_000030.png/  folder_frame_006441.png/  folder_frame_016053.png/
# folder_frame_000032.png/  folder_frame_006444.png/  folder_frame_016054.png/
# folder_frame_000033.png/  folder_frame_006448.png/  folder_frame_016055.png/
# folder_frame_000035.png/  folder_frame_006451.png/  folder_frame_016056.png/
# folder_frame_000036.png/  folder_frame_006454.png/  folder_frame_016057.png/
# folder_frame_000037.png/  folder_frame_006466.png/  folder_frame_016059.png/
# folder_frame_000038.png/  folder_frame_006469.png/  folder_frame_016060.png/
# folder_frame_000040.png/  folder_frame_006473.png/  folder_frame_016061.png/
# folder_frame_000041.png/  folder_frame_006476.png/  folder_frame_016062.png/
# folder_frame_000042.png/  folder_frame_006479.png/  folder_frame_016063.png/
# folder_frame_000044.png/  folder_frame_006482.png/  folder_frame_016064.png/
# folder_frame_000045.png/  folder_frame_006485.png/  folder_frame_016065.png/
# folder_frame_000046.png/  folder_frame_006488.png/  folder_frame_016066.png/
# folder_frame_000047.png/  folder_frame_006491.png/  folder_frame_016067.png/
# folder_frame_000048.png/  folder_frame_006504.png/  folder_frame_016068.png/
# folder_frame_000049.png/  folder_frame_006518.png/  folder_frame_016069.png/
# folder_frame_000050.png/  folder_frame_006524.png/  folder_frame_016070.png/
# folder_frame_000052.png/  folder_frame_006529.png/  folder_frame_016071.png/
# folder_frame_000053.png/  folder_frame_006532.png/  folder_frame_016072.png/
# folder_frame_000054.png/  folder_frame_006535.png/  folder_frame_016073.png/
# folder_frame_000055.png/  folder_frame_006538.png/  folder_frame_016074.png/
# folder_frame_000056.png/  folder_frame_006541.png/  folder_frame_016075.png/
# folder_frame_000057.png/  folder_frame_006554.png/  folder_frame_016076.png/
# folder_frame_000058.png/  folder_frame_006560.png/  folder_frame_016077.png/
# folder_frame_000059.png/  folder_frame_006563.png/  folder_frame_016078.png/
# folder_frame_000060.png/  folder_frame_006566.png/  folder_frame_016079.png/
# folder_frame_000061.png/  folder_frame_006570.png/  folder_frame_016080.png/
# folder_frame_000062.png/  folder_frame_006573.png/  folder_frame_016081.png/
# folder_frame_000063.png/  folder_frame_006576.png/  folder_frame_016083.png/
# folder_frame_000064.png/  folder_frame_006579.png/  folder_frame_016084.png/
# folder_frame_000065.png/  folder_frame_006582.png/  folder_frame_016085.png/
# folder_frame_000066.png/  folder_frame_006585.png/  folder_frame_016086.png/
# folder_frame_000067.png/  folder_frame_006588.png/  folder_frame_016087.png/
# folder_frame_000068.png/  folder_frame_006591.png/  folder_frame_016088.png/
# folder_frame_000069.png/  folder_frame_006595.png/  folder_frame_016089.png/
# folder_frame_000070.png/  folder_frame_006598.png/  folder_frame_016090.png/
# folder_frame_000071.png/  folder_frame_006601.png/  folder_frame_016091.png/
# folder_frame_000072.png/  folder_frame_006604.png/  folder_frame_016092.png/
# folder_frame_000073.png/  folder_frame_006607.png/  folder_frame_016093.png/
# folder_frame_000074.png/  folder_frame_006610.png/  folder_frame_016094.png/
# folder_frame_000076.png/  folder_frame_006612.png/  folder_frame_016095.png/
# folder_frame_000077.png/  folder_frame_006613.png/  folder_frame_016096.png/
# folder_frame_000078.png/  folder_frame_006614.png/  folder_frame_016097.png/
# folder_frame_000079.png/  folder_frame_006615.png/  folder_frame_016098.png/
# folder_frame_000080.png/  folder_frame_006616.png/  folder_frame_016099.png/
# folder_frame_000081.png/  folder_frame_006617.png/  folder_frame_016100.png/
# folder_frame_000082.png/  folder_frame_006619.png/  folder_frame_016101.png/
# folder_frame_000083.png/  folder_frame_006620.png/  folder_frame_016102.png/
# folder_frame_000084.png/  folder_frame_006621.png/  folder_frame_016103.png/
# folder_frame_000085.png/  folder_frame_006622.png/  folder_frame_016104.png/
# folder_frame_000086.png/  folder_frame_006623.png/  folder_frame_016105.png/
# folder_frame_000087.png/  folder_frame_006624.png/  folder_frame_016106.png/
# folder_frame_000088.png/  folder_frame_006625.png/  folder_frame_016108.png/
# folder_frame_000089.png/  folder_frame_006626.png/  folder_frame_016109.png/
# folder_frame_000090.png/  folder_frame_006627.png/  folder_frame_016110.png/
# folder_frame_000091.png/  folder_frame_006628.png/  folder_frame_016111.png/
# folder_frame_000092.png/  folder_frame_006629.png/  folder_frame_016112.png/
# folder_frame_000093.png/  folder_frame_006630.png/  folder_frame_016113.png/
# folder_frame_000094.png/  folder_frame_006631.png/  folder_frame_016114.png/
# folder_frame_000095.png/  folder_frame_006632.png/  folder_frame_016115.png/
# folder_frame_000096.png/  folder_frame_006633.png/  folder_frame_016116.png/
# folder_frame_000097.png/  folder_frame_006634.png/  folder_frame_016117.png/
# folder_frame_000098.png/  folder_frame_006635.png/  folder_frame_016118.png/
# folder_frame_000099.png/  folder_frame_006636.png/  folder_frame_016119.png/
# folder_frame_000101.png/  folder_frame_006637.png/  folder_frame_016120.png/
# folder_frame_000102.png/  folder_frame_006638.png/  folder_frame_016121.png/
# folder_frame_000103.png/  folder_frame_006639.png/  folder_frame_016122.png/
# folder_frame_000104.png/  folder_frame_006640.png/  folder_frame_016123.png/
# folder_frame_000105.png/  folder_frame_006641.png/  folder_frame_016124.png/
# folder_frame_000106.png/  folder_frame_006645.png/  folder_frame_016125.png/
# folder_frame_000107.png/  folder_frame_006648.png/  folder_frame_016126.png/
# folder_frame_000108.png/  folder_frame_006651.png/  folder_frame_016127.png/
# folder_frame_000109.png/  folder_frame_006670.png/  folder_frame_016128.png/
# folder_frame_000110.png/  folder_frame_006672.png/  folder_frame_016129.png/
# folder_frame_000111.png/  folder_frame_006674.png/  folder_frame_016130.png/
# folder_frame_000112.png/  folder_frame_006677.png/  folder_frame_016132.png/
# folder_frame_000113.png/  folder_frame_006680.png/  folder_frame_016133.png/
# folder_frame_000114.png/  folder_frame_006682.png/  folder_frame_016134.png/
# folder_frame_000115.png/  folder_frame_006685.png/  folder_frame_016135.png/
# folder_frame_000116.png/  folder_frame_006707.png/  folder_frame_016136.png/
# folder_frame_000117.png/  folder_frame_006710.png/  folder_frame_016137.png/
# folder_frame_000118.png/  folder_frame_006713.png/  folder_frame_016138.png/
# folder_frame_000119.png/  folder_frame_006729.png/  folder_frame_016139.png/
# folder_frame_000120.png/  folder_frame_006731.png/  folder_frame_016140.png/
# folder_frame_000121.png/  folder_frame_006733.png/  folder_frame_016141.png/
# folder_frame_000122.png/  folder_frame_006736.png/  folder_frame_016142.png/
# folder_frame_000123.png/  folder_frame_006739.png/  folder_frame_016143.png/
# folder_frame_000125.png/  folder_frame_006748.png/  folder_frame_016144.png/
# folder_frame_000126.png/  folder_frame_006750.png/  folder_frame_016145.png/
# folder_frame_000127.png/  folder_frame_006752.png/  folder_frame_016146.png/
# folder_frame_000128.png/  folder_frame_006754.png/  folder_frame_016147.png/
# folder_frame_000129.png/  folder_frame_006756.png/  folder_frame_016148.png/
# folder_frame_000130.png/  folder_frame_006758.png/  folder_frame_016149.png/
# folder_frame_000131.png/  folder_frame_006760.png/  folder_frame_016150.png/
# folder_frame_000132.png/  folder_frame_006762.png/  folder_frame_016151.png/
# folder_frame_000133.png/  folder_frame_006764.png/  folder_frame_016152.png/
# folder_frame_000134.png/  folder_frame_006768.png/  folder_frame_016153.png/
# folder_frame_000135.png/  folder_frame_006774.png/  folder_frame_016154.png/
# folder_frame_000136.png/  folder_frame_006777.png/  folder_frame_016155.png/
# folder_frame_000137.png/  folder_frame_006780.png/  folder_frame_016156.png/
# folder_frame_000138.png/  folder_frame_006783.png/  folder_frame_016157.png/
# folder_frame_000139.png/  folder_frame_006786.png/  folder_frame_016158.png/
# folder_frame_000140.png/  folder_frame_006790.png/  folder_frame_016159.png/
# folder_frame_000141.png/  folder_frame_006792.png/  folder_frame_016160.png/
# folder_frame_000142.png/  folder_frame_006794.png/  folder_frame_016161.png/
# folder_frame_000143.png/  folder_frame_006796.png/  folder_frame_016162.png/
# folder_frame_000144.png/  folder_frame_006798.png/  folder_frame_016163.png/
# folder_frame_000145.png/  folder_frame_006800.png/  folder_frame_016164.png/
# folder_frame_000146.png/  folder_frame_006802.png/  folder_frame_016165.png/
# folder_frame_000147.png/  folder_frame_006804.png/  folder_frame_016166.png/
# folder_frame_000149.png/  folder_frame_006806.png/  folder_frame_016167.png/
# folder_frame_000150.png/  folder_frame_006808.png/  folder_frame_016168.png/
# folder_frame_000151.png/  folder_frame_006810.png/  folder_frame_016169.png/
# folder_frame_000152.png/  folder_frame_006812.png/  folder_frame_016170.png/
# folder_frame_000153.png/  folder_frame_006815.png/  folder_frame_016171.png/
# folder_frame_000154.png/  folder_frame_006817.png/  folder_frame_016172.png/
# folder_frame_000155.png/  folder_frame_006820.png/  folder_frame_016173.png/
# folder_frame_000156.png/  folder_frame_006821.png/  folder_frame_016174.png/
# folder_frame_000157.png/  folder_frame_006822.png/  folder_frame_016175.png/
# folder_frame_000158.png/  folder_frame_006823.png/  folder_frame_016176.png/
# folder_frame_000159.png/  folder_frame_006824.png/  folder_frame_016177.png/
# folder_frame_000160.png/  folder_frame_006825.png/  folder_frame_016178.png/
# folder_frame_000161.png/  folder_frame_006826.png/  folder_frame_016179.png/
# folder_frame_000162.png/  folder_frame_006827.png/  folder_frame_016181.png/
# folder_frame_000163.png/  folder_frame_006828.png/  folder_frame_016182.png/
# folder_frame_000164.png/  folder_frame_006829.png/  folder_frame_016183.png/
# folder_frame_000165.png/  folder_frame_006830.png/  folder_frame_016184.png/
# folder_frame_000166.png/  folder_frame_006831.png/  folder_frame_016185.png/
# folder_frame_000167.png/  folder_frame_006832.png/  folder_frame_016186.png/
# folder_frame_000168.png/  folder_frame_006833.png/  folder_frame_016187.png/
# folder_frame_000169.png/  folder_frame_006834.png/  folder_frame_016188.png/
# folder_frame_000170.png/  folder_frame_006835.png/  folder_frame_016189.png/
# folder_frame_000171.png/  folder_frame_006836.png/  folder_frame_016190.png/
# folder_frame_000172.png/  folder_frame_006837.png/  folder_frame_016191.png/
# folder_frame_000174.png/  folder_frame_006839.png/  folder_frame_016192.png/
# folder_frame_000175.png/  folder_frame_006840.png/  folder_frame_016193.png/
# folder_frame_000176.png/  folder_frame_006841.png/  folder_frame_016194.png/
# folder_frame_000177.png/  folder_frame_006842.png/  folder_frame_016195.png/
# folder_frame_000178.png/  folder_frame_006843.png/  folder_frame_016196.png/
# folder_frame_000179.png/  folder_frame_006844.png/  folder_frame_016197.png/
# folder_frame_000180.png/  folder_frame_006845.png/  folder_frame_016198.png/
# folder_frame_000181.png/  folder_frame_006846.png/  folder_frame_016199.png/
# folder_frame_000182.png/  folder_frame_006847.png/  folder_frame_016200.png/
# folder_frame_000183.png/  folder_frame_006848.png/  folder_frame_016201.png/
# folder_frame_000184.png/  folder_frame_006857.png/  folder_frame_016202.png/
# folder_frame_000185.png/  folder_frame_006860.png/  folder_frame_016203.png/
# folder_frame_000186.png/  folder_frame_006864.png/  folder_frame_016205.png/
# folder_frame_000187.png/  folder_frame_006869.png/  folder_frame_016206.png/
# folder_frame_000188.png/  folder_frame_006873.png/  folder_frame_016207.png/
# folder_frame_000189.png/  folder_frame_006876.png/  folder_frame_016208.png/
# folder_frame_000190.png/  folder_frame_006879.png/  folder_frame_016209.png/
# folder_frame_000191.png/  folder_frame_006885.png/  folder_frame_016210.png/
# folder_frame_000192.png/  folder_frame_006904.png/  folder_frame_016211.png/
# folder_frame_000193.png/  folder_frame_006907.png/  folder_frame_016212.png/
# folder_frame_000194.png/  folder_frame_006910.png/  folder_frame_016213.png/
# folder_frame_000195.png/  folder_frame_006914.png/  folder_frame_016214.png/
# folder_frame_000196.png/  folder_frame_006917.png/  folder_frame_016215.png/
# folder_frame_000198.png/  folder_frame_006920.png/  folder_frame_016216.png/
# folder_frame_000199.png/  folder_frame_006923.png/  folder_frame_016217.png/
# folder_frame_000200.png/  folder_frame_006926.png/  folder_frame_016218.png/
# folder_frame_000201.png/  folder_frame_006929.png/  folder_frame_016219.png/
# folder_frame_000202.png/  folder_frame_006932.png/  folder_frame_016220.png/
# folder_frame_000203.png/  folder_frame_006935.png/  folder_frame_016221.png/
# folder_frame_000204.png/  folder_frame_006939.png/  folder_frame_016222.png/
# folder_frame_000205.png/  folder_frame_006942.png/  folder_frame_016223.png/
# folder_frame_000206.png/  folder_frame_006945.png/  folder_frame_016224.png/
# folder_frame_000207.png/  folder_frame_006948.png/  folder_frame_016225.png/
# folder_frame_000208.png/  folder_frame_006951.png/  folder_frame_016226.png/
# folder_frame_000209.png/  folder_frame_006954.png/  folder_frame_016227.png/
# folder_frame_000210.png/  folder_frame_006957.png/  folder_frame_016228.png/
# folder_frame_000211.png/  folder_frame_006960.png/  folder_frame_016230.png/
# folder_frame_000212.png/  folder_frame_006961.png/  folder_frame_016231.png/
# folder_frame_000213.png/  folder_frame_006964.png/  folder_frame_016232.png/
# folder_frame_000214.png/  folder_frame_006967.png/  folder_frame_016233.png/
# folder_frame_000215.png/  folder_frame_006970.png/  folder_frame_016234.png/
# folder_frame_000216.png/  folder_frame_006973.png/  folder_frame_016235.png/
# folder_frame_000217.png/  folder_frame_006976.png/  folder_frame_016236.png/
# folder_frame_000218.png/  folder_frame_006979.png/  folder_frame_016237.png/
# folder_frame_000219.png/  folder_frame_006982.png/  folder_frame_016238.png/
# folder_frame_000220.png/  folder_frame_006986.png/  folder_frame_016239.png/
# folder_frame_000221.png/  folder_frame_006989.png/  folder_frame_016240.png/
# folder_frame_000223.png/  folder_frame_006992.png/  folder_frame_016241.png/
# folder_frame_000224.png/  folder_frame_006995.png/  folder_frame_016242.png/
# folder_frame_000225.png/  folder_frame_006998.png/  folder_frame_016243.png/
# folder_frame_000226.png/  folder_frame_007001.png/  folder_frame_016244.png/
# folder_frame_000227.png/  folder_frame_007004.png/  folder_frame_016245.png/
# folder_frame_000228.png/  folder_frame_007007.png/  folder_frame_016246.png/
# folder_frame_000229.png/  folder_frame_007011.png/  folder_frame_016247.png/
# folder_frame_000230.png/  folder_frame_007014.png/  folder_frame_016248.png/
# folder_frame_000231.png/  folder_frame_007017.png/  folder_frame_016249.png/
# folder_frame_000232.png/  folder_frame_007028.png/  folder_frame_016250.png/
# folder_frame_000233.png/  folder_frame_007030.png/  folder_frame_016251.png/
# folder_frame_000234.png/  folder_frame_007032.png/  folder_frame_016252.png/
# folder_frame_000235.png/  folder_frame_007035.png/  folder_frame_016254.png/
# folder_frame_000236.png/  folder_frame_007038.png/  folder_frame_016255.png/
# folder_frame_000237.png/  folder_frame_007041.png/  folder_frame_016256.png/
# folder_frame_000238.png/  folder_frame_007050.png/  folder_frame_016257.png/
# folder_frame_000239.png/  folder_frame_007053.png/  folder_frame_016258.png/
# folder_frame_000240.png/  folder_frame_007056.png/  folder_frame_016259.png/
# folder_frame_000241.png/  folder_frame_007060.png/  folder_frame_016260.png/
# folder_frame_000242.png/  folder_frame_007063.png/  folder_frame_016261.png/
# folder_frame_000243.png/  folder_frame_007066.png/  folder_frame_016262.png/
# folder_frame_000244.png/  folder_frame_007080.png/  folder_frame_016263.png/
# folder_frame_000245.png/  folder_frame_007084.png/  folder_frame_016264.png/
# folder_frame_000247.png/  folder_frame_007087.png/  folder_frame_016265.png/
# folder_frame_000248.png/  folder_frame_007093.png/  folder_frame_016266.png/
# folder_frame_000249.png/  folder_frame_007102.png/  folder_frame_016267.png/
# folder_frame_000250.png/  folder_frame_007105.png/  folder_frame_016268.png/
# folder_frame_000251.png/  folder_frame_007112.png/  folder_frame_016269.png/
# folder_frame_000252.png/  folder_frame_007121.png/  folder_frame_016270.png/
# folder_frame_000253.png/  folder_frame_007123.png/  folder_frame_016271.png/
# folder_frame_000255.png/  folder_frame_007125.png/  folder_frame_016272.png/
# folder_frame_000281.png/  folder_frame_007127.png/  folder_frame_016273.png/
# folder_frame_000284.png/  folder_frame_007130.png/  folder_frame_016274.png/
# folder_frame_000287.png/  folder_frame_007133.png/  folder_frame_016275.png/
# folder_frame_000290.png/  folder_frame_007135.png/  folder_frame_016276.png/
# folder_frame_000293.png/  folder_frame_007138.png/  folder_frame_016278.png/
# folder_frame_000297.png/  folder_frame_007140.png/  folder_frame_016279.png/
# folder_frame_000299.png/  folder_frame_007142.png/  folder_frame_016280.png/
# folder_frame_000302.png/  folder_frame_007144.png/  folder_frame_016281.png/
# folder_frame_000304.png/  folder_frame_007146.png/  folder_frame_016282.png/
# folder_frame_000307.png/  folder_frame_007149.png/  folder_frame_016283.png/
# folder_frame_000311.png/  folder_frame_007151.png/  folder_frame_016284.png/
# folder_frame_000315.png/  folder_frame_007153.png/  folder_frame_016285.png/
# folder_frame_000320.png/  folder_frame_007156.png/  folder_frame_016286.png/
# folder_frame_000324.png/  folder_frame_007159.png/  folder_frame_016287.png/
# folder_frame_000327.png/  folder_frame_007162.png/  folder_frame_016288.png/
# folder_frame_000329.png/  folder_frame_007164.png/  folder_frame_016289.png/
# folder_frame_000331.png/  folder_frame_007166.png/  folder_frame_016290.png/
# folder_frame_000333.png/  folder_frame_007168.png/  folder_frame_016291.png/
# folder_frame_000335.png/  folder_frame_007171.png/  folder_frame_016292.png/
# folder_frame_000337.png/  folder_frame_007174.png/  folder_frame_016293.png/
# folder_frame_000340.png/  folder_frame_007177.png/  folder_frame_016294.png/
# folder_frame_000343.png/  folder_frame_007179.png/  folder_frame_016295.png/
# folder_frame_000420.png/  folder_frame_007182.png/  folder_frame_016296.png/
# folder_frame_000422.png/  folder_frame_007183.png/  folder_frame_016297.png/
# folder_frame_000424.png/  folder_frame_007184.png/  folder_frame_016298.png/
# folder_frame_000426.png/  folder_frame_007187.png/  folder_frame_016299.png/
# folder_frame_000428.png/  folder_frame_007190.png/  folder_frame_016300.png/
# folder_frame_000430.png/  folder_frame_007193.png/  folder_frame_016301.png/
# folder_frame_000432.png/  folder_frame_007196.png/  folder_frame_016303.png/
# folder_frame_000434.png/  folder_frame_007204.png/  folder_frame_016304.png/
# folder_frame_000436.png/  folder_frame_007209.png/  folder_frame_016305.png/
# folder_frame_000438.png/  folder_frame_007234.png/  folder_frame_016306.png/
# folder_frame_000440.png/  folder_frame_007256.png/  folder_frame_016307.png/
# folder_frame_000443.png/  folder_frame_007259.png/  folder_frame_016308.png/
# folder_frame_000445.png/  folder_frame_007262.png/  folder_frame_016309.png/
# folder_frame_000446.png/  folder_frame_007265.png/  folder_frame_016310.png/
# folder_frame_000448.png/  folder_frame_007268.png/  folder_frame_016311.png/
# folder_frame_000479.png/  folder_frame_007271.png/  folder_frame_016312.png/
# folder_frame_000480.png/  folder_frame_007274.png/  folder_frame_016313.png/
# folder_frame_000481.png/  folder_frame_007278.png/  folder_frame_016314.png/
# folder_frame_000482.png/  folder_frame_007281.png/  folder_frame_016315.png/
# folder_frame_000483.png/  folder_frame_007284.png/  folder_frame_016316.png/
# folder_frame_000484.png/  folder_frame_007287.png/  folder_frame_016317.png/
# folder_frame_000485.png/  folder_frame_007290.png/  folder_frame_016318.png/
# folder_frame_000486.png/  folder_frame_007293.png/  folder_frame_016319.png/
# folder_frame_000487.png/  folder_frame_007296.png/  folder_frame_016320.png/
# folder_frame_000488.png/  folder_frame_007299.png/  folder_frame_016321.png/
# folder_frame_000489.png/  folder_frame_007303.png/  folder_frame_016322.png/
# folder_frame_000491.png/  folder_frame_007306.png/  folder_frame_016323.png/
# folder_frame_000492.png/  folder_frame_007309.png/  folder_frame_016324.png/
# folder_frame_000493.png/  folder_frame_007312.png/  folder_frame_016325.png/
# folder_frame_000494.png/  folder_frame_007315.png/  folder_frame_016327.png/
# folder_frame_000495.png/  folder_frame_007318.png/  folder_frame_016328.png/
# folder_frame_000496.png/  folder_frame_007321.png/  folder_frame_016329.png/
# folder_frame_000497.png/  folder_frame_007324.png/  folder_frame_016330.png/
# folder_frame_000498.png/  folder_frame_007328.png/  folder_frame_016331.png/
# folder_frame_000499.png/  folder_frame_007331.png/  folder_frame_016332.png/
# folder_frame_000500.png/  folder_frame_007334.png/  folder_frame_016333.png/
# folder_frame_000501.png/  folder_frame_007337.png/  folder_frame_016334.png/
# folder_frame_000502.png/  folder_frame_007340.png/  folder_frame_016335.png/
# folder_frame_000503.png/  folder_frame_007343.png/  folder_frame_016336.png/
# folder_frame_000504.png/  folder_frame_007346.png/  folder_frame_016337.png/
# folder_frame_000505.png/  folder_frame_007349.png/  folder_frame_016338.png/
# folder_frame_000506.png/  folder_frame_007353.png/  folder_frame_016339.png/
# folder_frame_000507.png/  folder_frame_007356.png/  folder_frame_016340.png/
# folder_frame_000508.png/  folder_frame_007359.png/  folder_frame_016341.png/
# folder_frame_000509.png/  folder_frame_007379.png/  folder_frame_016342.png/
# folder_frame_000510.png/  folder_frame_007384.png/  folder_frame_016343.png/
# folder_frame_000511.png/  folder_frame_007395.png/  folder_frame_016344.png/
# folder_frame_000512.png/  folder_frame_007399.png/  folder_frame_016345.png/
# folder_frame_000513.png/  folder_frame_007403.png/  folder_frame_016346.png/
# folder_frame_000514.png/  folder_frame_007406.png/  folder_frame_016347.png/
# folder_frame_000516.png/  folder_frame_007409.png/  folder_frame_016348.png/
# folder_frame_000517.png/  folder_frame_007412.png/  folder_frame_016349.png/
# folder_frame_000518.png/  folder_frame_007415.png/  folder_frame_016350.png/
# folder_frame_000519.png/  folder_frame_007418.png/  folder_frame_016352.png/
# folder_frame_000520.png/  folder_frame_007421.png/  folder_frame_016353.png/
# folder_frame_000521.png/  folder_frame_007425.png/  folder_frame_016354.png/
# folder_frame_000522.png/  folder_frame_007428.png/  folder_frame_016355.png/
# folder_frame_000523.png/  folder_frame_007431.png/  folder_frame_016356.png/
# folder_frame_000524.png/  folder_frame_007434.png/  folder_frame_016357.png/
# folder_frame_000525.png/  folder_frame_007437.png/  folder_frame_016358.png/
# folder_frame_000526.png/  folder_frame_007440.png/  folder_frame_016359.png/
# folder_frame_000527.png/  folder_frame_007443.png/  folder_frame_016360.png/
# folder_frame_000528.png/  folder_frame_007446.png/  folder_frame_016361.png/
# folder_frame_000529.png/  folder_frame_007453.png/  folder_frame_016362.png/
# folder_frame_000530.png/  folder_frame_007459.png/  folder_frame_016363.png/
# folder_frame_000531.png/  folder_frame_007475.png/  folder_frame_016364.png/
# folder_frame_000532.png/  folder_frame_007490.png/  folder_frame_016365.png/
# folder_frame_000533.png/  folder_frame_007493.png/  folder_frame_016366.png/
# folder_frame_000534.png/  folder_frame_007496.png/  folder_frame_016367.png/
# folder_frame_000535.png/  folder_frame_007500.png/  folder_frame_016368.png/
# folder_frame_000536.png/  folder_frame_007503.png/  folder_frame_016369.png/
# folder_frame_000537.png/  folder_frame_007518.png/  folder_frame_016370.png/
# folder_frame_000538.png/  folder_frame_007519.png/  folder_frame_016371.png/
# folder_frame_000540.png/  folder_frame_007520.png/  folder_frame_016372.png/
# folder_frame_000541.png/  folder_frame_007521.png/  folder_frame_016373.png/
# folder_frame_000542.png/  folder_frame_007523.png/  folder_frame_016374.png/
# folder_frame_000543.png/  folder_frame_007524.png/  folder_frame_016376.png/
# folder_frame_000544.png/  folder_frame_007525.png/  folder_frame_016377.png/
# folder_frame_000545.png/  folder_frame_007526.png/  folder_frame_016378.png/
# folder_frame_000546.png/  folder_frame_007528.png/  folder_frame_016379.png/
# folder_frame_000547.png/  folder_frame_007530.png/  folder_frame_016380.png/
# folder_frame_000548.png/  folder_frame_007534.png/  folder_frame_016381.png/
# folder_frame_000549.png/  folder_frame_007535.png/  folder_frame_016382.png/
# folder_frame_000550.png/  folder_frame_007536.png/  folder_frame_016383.png/
# folder_frame_000551.png/  folder_frame_007537.png/  folder_frame_016384.png/
# folder_frame_000552.png/  folder_frame_007538.png/  folder_frame_016385.png/
# folder_frame_000553.png/  folder_frame_007539.png/  folder_frame_016386.png/
# folder_frame_000554.png/  folder_frame_007540.png/  folder_frame_016387.png/
# folder_frame_000555.png/  folder_frame_007541.png/  folder_frame_016388.png/
# folder_frame_000556.png/  folder_frame_007542.png/  folder_frame_016389.png/
# folder_frame_000557.png/  folder_frame_007543.png/  folder_frame_016390.png/
# folder_frame_000558.png/  folder_frame_007544.png/  folder_frame_016391.png/
# folder_frame_000559.png/  folder_frame_007545.png/  folder_frame_016392.png/
# folder_frame_000560.png/  folder_frame_007547.png/  folder_frame_016393.png/
# folder_frame_000561.png/  folder_frame_007548.png/  folder_frame_016396.png/
# folder_frame_000562.png/  folder_frame_007549.png/  folder_frame_016399.png/
# folder_frame_000564.png/  folder_frame_007550.png/  folder_frame_016403.png/
# folder_frame_000565.png/  folder_frame_007551.png/  folder_frame_016406.png/
# folder_frame_000566.png/  folder_frame_007552.png/  folder_frame_016409.png/
# folder_frame_000567.png/  folder_frame_007553.png/  folder_frame_016412.png/
# folder_frame_000568.png/  folder_frame_007554.png/  folder_frame_016415.png/
# folder_frame_000569.png/  folder_frame_007555.png/  folder_frame_016418.png/
# folder_frame_000570.png/  folder_frame_007556.png/  folder_frame_016421.png/
# folder_frame_000571.png/  folder_frame_007557.png/  folder_frame_016425.png/
# folder_frame_000572.png/  folder_frame_007558.png/  folder_frame_016428.png/
# folder_frame_000573.png/  folder_frame_007559.png/  folder_frame_016431.png/
# folder_frame_000574.png/  folder_frame_007560.png/  folder_frame_016434.png/
# folder_frame_000575.png/  folder_frame_007561.png/  folder_frame_016437.png/
# folder_frame_000576.png/  folder_frame_007562.png/  folder_frame_016440.png/
# folder_frame_000577.png/  folder_frame_007563.png/  folder_frame_016443.png/
# folder_frame_000578.png/  folder_frame_007564.png/  folder_frame_016446.png/
# folder_frame_000579.png/  folder_frame_007565.png/  folder_frame_016450.png/
# folder_frame_000580.png/  folder_frame_007566.png/  folder_frame_016453.png/
# folder_frame_000581.png/  folder_frame_007567.png/  folder_frame_016456.png/
# folder_frame_000582.png/  folder_frame_007568.png/  folder_frame_016459.png/
# folder_frame_000583.png/  folder_frame_007569.png/  folder_frame_016462.png/
# folder_frame_000584.png/  folder_frame_007571.png/  folder_frame_016465.png/
# folder_frame_000585.png/  folder_frame_007572.png/  folder_frame_016468.png/
# folder_frame_000586.png/  folder_frame_007573.png/  folder_frame_016471.png/
# folder_frame_000587.png/  folder_frame_007574.png/  folder_frame_016475.png/
# folder_frame_000589.png/  folder_frame_007575.png/  folder_frame_016478.png/
# folder_frame_000590.png/  folder_frame_007576.png/  folder_frame_016481.png/
# folder_frame_000591.png/  folder_frame_007577.png/  folder_frame_016484.png/
# folder_frame_000592.png/  folder_frame_007578.png/  folder_frame_016487.png/
# folder_frame_000593.png/  folder_frame_007579.png/  folder_frame_016490.png/
# folder_frame_000594.png/  folder_frame_007580.png/  folder_frame_016493.png/
# folder_frame_000595.png/  folder_frame_007581.png/  folder_frame_016496.png/
# folder_frame_000596.png/  folder_frame_007582.png/  folder_frame_016500.png/
# folder_frame_000597.png/  folder_frame_007583.png/  folder_frame_016503.png/
# folder_frame_000598.png/  folder_frame_007584.png/  folder_frame_016506.png/
# folder_frame_000599.png/  folder_frame_007585.png/  folder_frame_016515.png/
# folder_frame_000600.png/  folder_frame_007586.png/  folder_frame_016522.png/
# folder_frame_000601.png/  folder_frame_007587.png/  folder_frame_016526.png/
# folder_frame_000602.png/  folder_frame_007588.png/  folder_frame_016528.png/
# folder_frame_000603.png/  folder_frame_007589.png/  folder_frame_016531.png/
# folder_frame_000604.png/  folder_frame_007590.png/  folder_frame_016540.png/
# folder_frame_000605.png/  folder_frame_007591.png/  folder_frame_016547.png/
# folder_frame_000606.png/  folder_frame_007592.png/  folder_frame_016553.png/
# folder_frame_000607.png/  folder_frame_007593.png/  folder_frame_016556.png/
# folder_frame_000608.png/  folder_frame_007594.png/  folder_frame_016559.png/
# folder_frame_000609.png/  folder_frame_007596.png/  folder_frame_016562.png/
# folder_frame_000610.png/  folder_frame_007597.png/  folder_frame_016565.png/
# folder_frame_000611.png/  folder_frame_007598.png/  folder_frame_016568.png/
# folder_frame_000613.png/  folder_frame_007599.png/  folder_frame_016572.png/
# folder_frame_000614.png/  folder_frame_007600.png/  folder_frame_016575.png/
# folder_frame_000615.png/  folder_frame_007601.png/  folder_frame_016578.png/
# folder_frame_000616.png/  folder_frame_007602.png/  folder_frame_016581.png/
# folder_frame_000617.png/  folder_frame_007603.png/  folder_frame_016584.png/
# folder_frame_000618.png/  folder_frame_007604.png/  folder_frame_016587.png/
# folder_frame_000619.png/  folder_frame_007605.png/  folder_frame_016590.png/
# folder_frame_000620.png/  folder_frame_007606.png/  folder_frame_016593.png/
# folder_frame_000621.png/  folder_frame_007607.png/  folder_frame_016597.png/
# folder_frame_000622.png/  folder_frame_007608.png/  folder_frame_016600.png/
# folder_frame_000623.png/  folder_frame_007609.png/  folder_frame_016603.png/
# folder_frame_000624.png/  folder_frame_007610.png/  folder_frame_016606.png/
# folder_frame_000625.png/  folder_frame_007611.png/  folder_frame_016609.png/
# folder_frame_000626.png/  folder_frame_007612.png/  folder_frame_016612.png/
# folder_frame_000627.png/  folder_frame_007613.png/  folder_frame_016615.png/
# folder_frame_000628.png/  folder_frame_007614.png/  folder_frame_016618.png/
# folder_frame_000629.png/  folder_frame_007615.png/  folder_frame_016620.png/
# folder_frame_000630.png/  folder_frame_007616.png/  folder_frame_016621.png/
# folder_frame_000631.png/  folder_frame_007617.png/  folder_frame_016622.png/
# folder_frame_000632.png/  folder_frame_007618.png/  folder_frame_016623.png/
# folder_frame_000633.png/  folder_frame_007620.png/  folder_frame_016624.png/
# folder_frame_000634.png/  folder_frame_007621.png/  folder_frame_016625.png/
# folder_frame_000635.png/  folder_frame_007622.png/  folder_frame_016626.png/
# folder_frame_000636.png/  folder_frame_007623.png/  folder_frame_016627.png/
# folder_frame_000638.png/  folder_frame_007624.png/  folder_frame_016628.png/
# folder_frame_000639.png/  folder_frame_007625.png/  folder_frame_016629.png/
# folder_frame_000640.png/  folder_frame_007626.png/  folder_frame_016630.png/
# folder_frame_000641.png/  folder_frame_007627.png/  folder_frame_016631.png/
# folder_frame_000642.png/  folder_frame_007628.png/  folder_frame_016632.png/
# folder_frame_000643.png/  folder_frame_007629.png/  folder_frame_016633.png/
# folder_frame_000644.png/  folder_frame_007630.png/  folder_frame_016634.png/
# folder_frame_000645.png/  folder_frame_007631.png/  folder_frame_016635.png/
# folder_frame_000646.png/  folder_frame_007632.png/  folder_frame_016636.png/
# folder_frame_000647.png/  folder_frame_007633.png/  folder_frame_016637.png/
# folder_frame_000648.png/  folder_frame_007634.png/  folder_frame_016638.png/
# folder_frame_000649.png/  folder_frame_007635.png/  folder_frame_016639.png/
# folder_frame_000650.png/  folder_frame_007636.png/  folder_frame_016640.png/
# folder_frame_000651.png/  folder_frame_007637.png/  folder_frame_016641.png/
# folder_frame_000652.png/  folder_frame_007638.png/  folder_frame_016642.png/
# folder_frame_000653.png/  folder_frame_007639.png/  folder_frame_016643.png/
# folder_frame_000654.png/  folder_frame_007640.png/  folder_frame_016645.png/
# folder_frame_000655.png/  folder_frame_007641.png/  folder_frame_016646.png/
# folder_frame_000656.png/  folder_frame_007642.png/  folder_frame_016647.png/
# folder_frame_000657.png/  folder_frame_007643.png/  folder_frame_016649.png/
# folder_frame_000658.png/  folder_frame_007645.png/  folder_frame_016650.png/
# folder_frame_000659.png/  folder_frame_007646.png/  folder_frame_016652.png/
# folder_frame_000660.png/  folder_frame_007647.png/  folder_frame_016653.png/
# folder_frame_000662.png/  folder_frame_007659.png/  folder_frame_016655.png/
# folder_frame_000663.png/  folder_frame_007672.png/  folder_frame_016656.png/
# folder_frame_000664.png/  folder_frame_007697.png/  folder_frame_016658.png/
# folder_frame_000665.png/  folder_frame_007727.png/  folder_frame_016659.png/
# folder_frame_000666.png/  folder_frame_007729.png/  folder_frame_016661.png/
# folder_frame_000667.png/  folder_frame_007731.png/  folder_frame_016662.png/
# folder_frame_000668.png/  folder_frame_007734.png/  folder_frame_016664.png/
# folder_frame_000669.png/  folder_frame_007737.png/  folder_frame_016665.png/
# folder_frame_000670.png/  folder_frame_007739.png/  folder_frame_016667.png/
# folder_frame_000671.png/  folder_frame_007742.png/  folder_frame_016669.png/
# folder_frame_000672.png/  folder_frame_007744.png/  folder_frame_016671.png/
# folder_frame_000673.png/  folder_frame_007746.png/  folder_frame_016672.png/
# folder_frame_000674.png/  folder_frame_007748.png/  folder_frame_016674.png/
# folder_frame_000675.png/  folder_frame_007750.png/  folder_frame_016675.png/
# folder_frame_000676.png/  folder_frame_007752.png/  folder_frame_016677.png/
# folder_frame_000677.png/  folder_frame_007754.png/  folder_frame_016678.png/
# folder_frame_000678.png/  folder_frame_007756.png/  folder_frame_016680.png/
# folder_frame_000679.png/  folder_frame_007759.png/  folder_frame_016681.png/
# folder_frame_000680.png/  folder_frame_007761.png/  folder_frame_016683.png/
# folder_frame_000681.png/  folder_frame_007764.png/  folder_frame_016684.png/
# folder_frame_000682.png/  folder_frame_007767.png/  folder_frame_016686.png/
# folder_frame_000683.png/  folder_frame_007769.png/  folder_frame_016687.png/
# folder_frame_000684.png/  folder_frame_007771.png/  folder_frame_016688.png/
# folder_frame_000685.png/  folder_frame_007773.png/  folder_frame_016690.png/
# folder_frame_000687.png/  folder_frame_007775.png/  folder_frame_016691.png/
# folder_frame_000688.png/  folder_frame_007776.png/  folder_frame_016692.png/
# folder_frame_000689.png/  folder_frame_007777.png/  folder_frame_016694.png/
# folder_frame_000690.png/  folder_frame_007779.png/  folder_frame_016695.png/
# folder_frame_000691.png/  folder_frame_007781.png/  folder_frame_016696.png/
# folder_frame_000692.png/  folder_frame_007783.png/  folder_frame_016697.png/
# folder_frame_000693.png/  folder_frame_007785.png/  folder_frame_016699.png/
# folder_frame_000694.png/  folder_frame_007788.png/  folder_frame_016700.png/
# folder_frame_000695.png/  folder_frame_007791.png/  folder_frame_016702.png/
# folder_frame_000696.png/  folder_frame_007793.png/  folder_frame_016703.png/
# folder_frame_000697.png/  folder_frame_007795.png/  folder_frame_016704.png/
# folder_frame_000698.png/  folder_frame_007796.png/  folder_frame_016705.png/
# folder_frame_000699.png/  folder_frame_007797.png/  folder_frame_016706.png/
# folder_frame_000700.png/  folder_frame_007798.png/  folder_frame_016708.png/
# folder_frame_000701.png/  folder_frame_007799.png/  folder_frame_016709.png/
# folder_frame_000702.png/  folder_frame_007800.png/  folder_frame_016710.png/
# folder_frame_000703.png/  folder_frame_007801.png/  folder_frame_016711.png/
# folder_frame_000704.png/  folder_frame_007802.png/  folder_frame_016712.png/
# folder_frame_000705.png/  folder_frame_007803.png/  folder_frame_016713.png/
# folder_frame_000706.png/  folder_frame_007805.png/  folder_frame_016715.png/
# folder_frame_000707.png/  folder_frame_007807.png/  folder_frame_016716.png/
# folder_frame_000708.png/  folder_frame_007809.png/  folder_frame_016718.png/
# folder_frame_000709.png/  folder_frame_007811.png/  folder_frame_016719.png/
# folder_frame_000711.png/  folder_frame_007813.png/  folder_frame_016720.png/
# folder_frame_000712.png/  folder_frame_007816.png/  folder_frame_016721.png/
# folder_frame_000713.png/  folder_frame_007818.png/  folder_frame_016722.png/
# folder_frame_000714.png/  folder_frame_007820.png/  folder_frame_016723.png/
# folder_frame_000715.png/  folder_frame_007822.png/  folder_frame_016724.png/
# folder_frame_000716.png/  folder_frame_007824.png/  folder_frame_016725.png/
# folder_frame_000717.png/  folder_frame_007826.png/  folder_frame_016727.png/
# folder_frame_000718.png/  folder_frame_007828.png/  folder_frame_016728.png/
# folder_frame_000719.png/  folder_frame_007830.png/  folder_frame_016730.png/
# folder_frame_000720.png/  folder_frame_007831.png/  folder_frame_016731.png/
# folder_frame_000721.png/  folder_frame_007832.png/  folder_frame_016733.png/
# folder_frame_000722.png/  folder_frame_007834.png/  folder_frame_016734.png/
# folder_frame_000723.png/  folder_frame_007836.png/  folder_frame_016736.png/
# folder_frame_000724.png/  folder_frame_007837.png/  folder_frame_016737.png/
# folder_frame_000725.png/  folder_frame_007838.png/  folder_frame_016739.png/
# folder_frame_000726.png/  folder_frame_007841.png/  folder_frame_016740.png/
# folder_frame_000727.png/  folder_frame_007842.png/  folder_frame_016742.png/
# folder_frame_000728.png/  folder_frame_007843.png/  folder_frame_016744.png/
# folder_frame_000729.png/  folder_frame_007845.png/  folder_frame_016746.png/
# folder_frame_000730.png/  folder_frame_007847.png/  folder_frame_016748.png/
# folder_frame_000731.png/  folder_frame_007848.png/  folder_frame_016749.png/
# folder_frame_000732.png/  folder_frame_007849.png/  folder_frame_016750.png/
# folder_frame_000733.png/  folder_frame_007850.png/  folder_frame_016752.png/
# folder_frame_000735.png/  folder_frame_007851.png/  folder_frame_016754.png/
# folder_frame_000736.png/  folder_frame_007852.png/  folder_frame_016756.png/
# folder_frame_000737.png/  folder_frame_007853.png/  folder_frame_016758.png/
# folder_frame_000738.png/  folder_frame_007854.png/  folder_frame_016760.png/
# folder_frame_000739.png/  folder_frame_007855.png/  folder_frame_016761.png/
# folder_frame_000740.png/  folder_frame_007856.png/  folder_frame_016763.png/
# folder_frame_000741.png/  folder_frame_007857.png/  folder_frame_016765.png/
# folder_frame_000742.png/  folder_frame_007858.png/  folder_frame_016769.png/
# folder_frame_000743.png/  folder_frame_007859.png/  folder_frame_016772.png/
# folder_frame_000744.png/  folder_frame_007860.png/  folder_frame_016775.png/
# folder_frame_000745.png/  folder_frame_007861.png/  folder_frame_016778.png/
# folder_frame_000746.png/  folder_frame_007862.png/  folder_frame_016781.png/
# folder_frame_000747.png/  folder_frame_007864.png/  folder_frame_016784.png/
# folder_frame_000748.png/  folder_frame_007865.png/  folder_frame_016787.png/
# folder_frame_000749.png/  folder_frame_007866.png/  folder_frame_016791.png/
# folder_frame_000750.png/  folder_frame_007867.png/  folder_frame_016794.png/
# folder_frame_000751.png/  folder_frame_007868.png/  folder_frame_016797.png/
# folder_frame_000752.png/  folder_frame_007869.png/  folder_frame_016800.png/
# folder_frame_000753.png/  folder_frame_007870.png/  folder_frame_016803.png/
# folder_frame_000754.png/  folder_frame_007871.png/  folder_frame_016806.png/
# folder_frame_000755.png/  folder_frame_007872.png/  folder_frame_016809.png/
# folder_frame_000756.png/  folder_frame_007873.png/  folder_frame_016812.png/
# folder_frame_000757.png/  folder_frame_007874.png/  folder_frame_016816.png/
# folder_frame_000758.png/  folder_frame_007875.png/  folder_frame_016819.png/
# folder_frame_000760.png/  folder_frame_007876.png/  folder_frame_016822.png/
# folder_frame_000761.png/  folder_frame_007877.png/  folder_frame_016825.png/
# folder_frame_000762.png/  folder_frame_007878.png/  folder_frame_016828.png/
# folder_frame_000763.png/  folder_frame_007879.png/  folder_frame_016831.png/
# folder_frame_000764.png/  folder_frame_007880.png/  folder_frame_016834.png/
# folder_frame_000765.png/  folder_frame_007881.png/  folder_frame_016841.png/
# folder_frame_000766.png/  folder_frame_007882.png/  folder_frame_016844.png/
# folder_frame_000767.png/  folder_frame_007883.png/  folder_frame_016847.png/
# folder_frame_000768.png/  folder_frame_007884.png/  folder_frame_016850.png/
# folder_frame_000769.png/  folder_frame_007885.png/  folder_frame_016856.png/
# folder_frame_000770.png/  folder_frame_007886.png/  folder_frame_016859.png/
# folder_frame_000771.png/  folder_frame_007887.png/  folder_frame_016862.png/
# folder_frame_000772.png/  folder_frame_007889.png/  folder_frame_016866.png/
# folder_frame_000773.png/  folder_frame_007890.png/  folder_frame_016869.png/
# folder_frame_000774.png/  folder_frame_007891.png/  folder_frame_016872.png/
# folder_frame_000775.png/  folder_frame_007893.png/  folder_frame_016875.png/
# folder_frame_000776.png/  folder_frame_007895.png/  folder_frame_016891.png/
# folder_frame_000777.png/  folder_frame_007897.png/  folder_frame_016894.png/
# folder_frame_000778.png/  folder_frame_007899.png/  folder_frame_016897.png/
# folder_frame_000779.png/  folder_frame_007901.png/  folder_frame_016900.png/
# folder_frame_000780.png/  folder_frame_007903.png/  folder_frame_016903.png/
# folder_frame_000781.png/  folder_frame_007905.png/  folder_frame_016906.png/
# folder_frame_000782.png/  folder_frame_007906.png/  folder_frame_016909.png/
# folder_frame_000784.png/  folder_frame_007907.png/  folder_frame_016913.png/
# folder_frame_000785.png/  folder_frame_007908.png/  folder_frame_016916.png/
# folder_frame_000786.png/  folder_frame_007909.png/  folder_frame_016919.png/
# folder_frame_000787.png/  folder_frame_007910.png/  folder_frame_016925.png/
# folder_frame_000788.png/  folder_frame_007911.png/  folder_frame_016928.png/
# folder_frame_000789.png/  folder_frame_007913.png/  folder_frame_016931.png/
# folder_frame_000790.png/  folder_frame_007914.png/  folder_frame_016934.png/
# folder_frame_000791.png/  folder_frame_007915.png/  folder_frame_016936.png/
# folder_frame_000792.png/  folder_frame_007916.png/  folder_frame_016938.png/
# folder_frame_000793.png/  folder_frame_007917.png/  folder_frame_016939.png/
# folder_frame_000794.png/  folder_frame_007918.png/  folder_frame_016940.png/
# folder_frame_000795.png/  folder_frame_007919.png/  folder_frame_016941.png/
# folder_frame_000796.png/  folder_frame_007920.png/  folder_frame_016942.png/
# folder_frame_000797.png/  folder_frame_007921.png/  folder_frame_016944.png/
# folder_frame_000798.png/  folder_frame_007922.png/  folder_frame_016947.png/
# folder_frame_000799.png/  folder_frame_007923.png/  folder_frame_016950.png/
# folder_frame_000800.png/  folder_frame_007924.png/  folder_frame_016953.png/
# folder_frame_000801.png/  folder_frame_007925.png/  folder_frame_016956.png/
# folder_frame_000802.png/  folder_frame_007926.png/  folder_frame_016963.png/
# folder_frame_000803.png/  folder_frame_007927.png/  folder_frame_016966.png/
# folder_frame_000804.png/  folder_frame_007928.png/  folder_frame_016968.png/
# folder_frame_000805.png/  folder_frame_007929.png/  folder_frame_016969.png/
# folder_frame_000806.png/  folder_frame_007930.png/  folder_frame_016970.png/
# folder_frame_000807.png/  folder_frame_007931.png/  folder_frame_016971.png/
# folder_frame_000809.png/  folder_frame_007932.png/  folder_frame_016972.png/
# folder_frame_000810.png/  folder_frame_007933.png/  folder_frame_016973.png/
# folder_frame_000811.png/  folder_frame_007934.png/  folder_frame_016974.png/
# folder_frame_000812.png/  folder_frame_007935.png/  folder_frame_016975.png/
# folder_frame_000813.png/  folder_frame_007936.png/  folder_frame_016976.png/
# folder_frame_000814.png/  folder_frame_007938.png/  folder_frame_016977.png/
# folder_frame_000815.png/  folder_frame_007939.png/  folder_frame_016978.png/
# folder_frame_000816.png/  folder_frame_007940.png/  folder_frame_016979.png/
# folder_frame_000817.png/  folder_frame_007941.png/  folder_frame_016980.png/
# folder_frame_000818.png/  folder_frame_007942.png/  folder_frame_016981.png/
# folder_frame_000819.png/  folder_frame_007943.png/  folder_frame_016982.png/
# folder_frame_000820.png/  folder_frame_007944.png/  folder_frame_016983.png/
# folder_frame_000821.png/  folder_frame_007945.png/  folder_frame_016984.png/
# folder_frame_000822.png/  folder_frame_007946.png/  folder_frame_016985.png/
# folder_frame_000823.png/  folder_frame_007947.png/  folder_frame_016987.png/
# folder_frame_000824.png/  folder_frame_007948.png/  folder_frame_016988.png/
# folder_frame_000825.png/  folder_frame_007949.png/  folder_frame_016989.png/
# folder_frame_000826.png/  folder_frame_007950.png/  folder_frame_016990.png/
# folder_frame_000827.png/  folder_frame_007951.png/  folder_frame_016991.png/
# folder_frame_000828.png/  folder_frame_007952.png/  folder_frame_016992.png/
# folder_frame_000829.png/  folder_frame_007953.png/  folder_frame_016993.png/
# folder_frame_000830.png/  folder_frame_007954.png/  folder_frame_016994.png/
# folder_frame_000831.png/  folder_frame_007955.png/  folder_frame_016995.png/
# folder_frame_000833.png/  folder_frame_007958.png/  folder_frame_016996.png/
# folder_frame_000834.png/  folder_frame_007962.png/  folder_frame_016997.png/
# folder_frame_000835.png/  folder_frame_007965.png/  folder_frame_017000.png/
# folder_frame_000836.png/  folder_frame_007968.png/  folder_frame_017005.png/
# folder_frame_000837.png/  folder_frame_007971.png/  folder_frame_017006.png/
# folder_frame_000838.png/  folder_frame_007974.png/  folder_frame_017007.png/
# folder_frame_000839.png/  folder_frame_007977.png/  folder_frame_017008.png/
# folder_frame_000840.png/  folder_frame_007980.png/  folder_frame_017009.png/
# folder_frame_000841.png/  folder_frame_007983.png/  folder_frame_017011.png/
# folder_frame_000842.png/  folder_frame_007987.png/  folder_frame_017012.png/
# folder_frame_000843.png/  folder_frame_007990.png/  folder_frame_017013.png/
# folder_frame_000844.png/  folder_frame_007993.png/  folder_frame_017014.png/
# folder_frame_000845.png/  folder_frame_007996.png/  folder_frame_017015.png/
# folder_frame_000846.png/  folder_frame_007999.png/  folder_frame_017016.png/
# folder_frame_000847.png/  folder_frame_008002.png/  folder_frame_017017.png/
# folder_frame_000848.png/  folder_frame_008005.png/  folder_frame_017018.png/
# folder_frame_000849.png/  folder_frame_008008.png/  folder_frame_017019.png/
# ...
# folder_frame_005973.png/  folder_frame_015822.png/  folder_frame_025711.png/
# folder_frame_005975.png/  folder_frame_015823.png/  folder_frame_025712.png/
# folder_frame_005977.png/  folder_frame_015824.png/  folder_frame_025713.png/
# folder_frame_005978.png/  folder_frame_015825.png/  folder_frame_025714.png/
# folder_frame_005979.png/  folder_frame_015826.png/  folder_frame_025715.png/
# folder_frame_005982.png/  folder_frame_015827.png/  folder_frame_025717.png/
# folder_frame_005986.png/  folder_frame_015828.png/  folder_frame_025718.png/
# folder_frame_005989.png/  folder_frame_015829.png/  folder_frame_025719.png/
# folder_frame_005991.png/  folder_frame_015830.png/  folder_frame_025720.png/
# folder_frame_006008.png/  folder_frame_015831.png/  folder_frame_025721.png/
# folder_frame_006028.png/  folder_frame_015832.png/  folder_frame_025722.png/
# folder_frame_006031.png/  folder_frame_015833.png/  folder_frame_025723.png/
# folder_frame_006035.png/  folder_frame_015834.png/  folder_frame_025724.png/
# folder_frame_006038.png/  folder_frame_015835.png/  folder_frame_025725.png/
# folder_frame_006041.png/  folder_frame_015836.png/  folder_frame_025726.png/
# folder_frame_006044.png/  folder_frame_015837.png/  folder_frame_025727.png/
# folder_frame_006047.png/  folder_frame_015839.png/  folder_frame_025728.png/
# folder_frame_006053.png/  folder_frame_015840.png/  folder_frame_025729.png/
# folder_frame_006056.png/  folder_frame_015841.png/  folder_frame_025730.png/
# folder_frame_006060.png/  folder_frame_015842.png/  folder_frame_025731.png/
# folder_frame_006063.png/  folder_frame_015843.png/  folder_frame_025732.png/
# folder_frame_006066.png/  folder_frame_015844.png/  folder_frame_025733.png/
# folder_frame_006069.png/  folder_frame_015845.png/  folder_frame_025734.png/
# folder_frame_006072.png/  folder_frame_015846.png/  folder_frame_025735.png/
# folder_frame_006075.png/  folder_frame_015847.png/  folder_frame_025736.png/
# folder_frame_006078.png/  folder_frame_015848.png/  folder_frame_025737.png/
# folder_frame_006082.png/  folder_frame_015849.png/  folder_frame_025738.png/
# folder_frame_006085.png/  folder_frame_015850.png/  folder_frame_025739.png/
# folder_frame_006088.png/  folder_frame_015851.png/  folder_frame_025741.png/
# folder_frame_006091.png/  folder_frame_015852.png/  folder_frame_025742.png/
# folder_frame_006099.png/  folder_frame_015853.png/  folder_frame_025743.png/
# folder_frame_006109.png/  folder_frame_015854.png/  folder_frame_025744.png/
# folder_frame_006113.png/  folder_frame_015855.png/  folder_frame_025745.png/
# folder_frame_006116.png/  folder_frame_015856.png/  folder_frame_025746.png/
# folder_frame_006119.png/  folder_frame_015857.png/  folder_frame_025747.png/
# folder_frame_006122.png/  folder_frame_015858.png/  folder_frame_025748.png/
# folder_frame_006125.png/  folder_frame_015859.png/  folder_frame_025749.png/
# folder_frame_006128.png/  folder_frame_015860.png/  folder_frame_025750.png/
# folder_frame_006141.png/  folder_frame_015861.png/  folder_frame_025751.png/
# folder_frame_006153.png/  folder_frame_015863.png/  folder_frame_025752.png/
# folder_frame_006157.png/  folder_frame_015864.png/  folder_frame_025753.png/
# folder_frame_006160.png/  folder_frame_015865.png/  folder_frame_025754.png/
# folder_frame_006163.png/  folder_frame_015866.png/  folder_frame_025755.png/
# folder_frame_006166.png/  folder_frame_015867.png/  folder_frame_025756.png/
# folder_frame_006168.png/  folder_frame_015868.png/  folder_frame_025757.png/
# folder_frame_006169.png/  folder_frame_015869.png/  folder_frame_025758.png/
# folder_frame_006170.png/  folder_frame_015870.png/  folder_frame_025759.png/
# folder_frame_006171.png/  folder_frame_015871.png/  folder_frame_025760.png/
# folder_frame_006172.png/  folder_frame_015872.png/  folder_frame_025761.png/
# folder_frame_006173.png/  folder_frame_015873.png/  folder_frame_025762.png/
# folder_frame_006174.png/  folder_frame_015874.png/  folder_frame_025763.png/
# folder_frame_006175.png/  folder_frame_015875.png/  folder_frame_025764.png/
# folder_frame_006176.png/  folder_frame_015876.png/  folder_frame_025766.png/
# folder_frame_006177.png/  folder_frame_015877.png/  folder_frame_025767.png/
# folder_frame_006178.png/  folder_frame_015878.png/  folder_frame_025768.png/
# folder_frame_006180.png/  folder_frame_015879.png/  folder_frame_025769.png/
# folder_frame_006181.png/  folder_frame_015880.png/  folder_frame_025770.png/
# folder_frame_006182.png/  folder_frame_015881.png/  folder_frame_025771.png/
# folder_frame_006183.png/  folder_frame_015882.png/  folder_frame_025772.png/
# folder_frame_006184.png/  folder_frame_015883.png/  folder_frame_025773.png/
# folder_frame_006185.png/  folder_frame_015884.png/  folder_frame_025774.png/
# folder_frame_006186.png/  folder_frame_015885.png/  folder_frame_025775.png/
# folder_frame_006187.png/  folder_frame_015886.png/  folder_frame_025776.png/
# folder_frame_006188.png/  folder_frame_015888.png/  folder_frame_025777.png/
# folder_frame_006189.png/  folder_frame_015889.png/  folder_frame_025778.png/
# folder_frame_006190.png/  folder_frame_015890.png/  folder_frame_025779.png/
# folder_frame_006191.png/  folder_frame_015891.png/  folder_frame_025780.png/
# folder_frame_006192.png/  folder_frame_015892.png/  folder_frame_025781.png/
# folder_frame_006193.png/  folder_frame_015893.png/  folder_frame_025782.png/
# folder_frame_006194.png/  folder_frame_015894.png/  folder_frame_025783.png/
# folder_frame_006195.png/  folder_frame_015895.png/  folder_frame_025784.png/
# folder_frame_006196.png/  folder_frame_015896.png/  folder_frame_025785.png/
# folder_frame_006197.png/  folder_frame_015897.png/  folder_frame_025786.png/
# folder_frame_006198.png/  folder_frame_015898.png/  folder_frame_025787.png/
# folder_frame_006199.png/  folder_frame_015899.png/  folder_frame_025788.png/
# folder_frame_006200.png/  folder_frame_015900.png/  folder_frame_025790.png/
# folder_frame_006201.png/  folder_frame_015901.png/  folder_frame_025791.png/
# folder_frame_006202.png/  folder_frame_015902.png/  folder_frame_025792.png/
# folder_frame_006204.png/  folder_frame_015903.png/  folder_frame_025793.png/
# folder_frame_006205.png/  folder_frame_015904.png/  folder_frame_025794.png/
# folder_frame_006206.png/  folder_frame_015905.png/  folder_frame_025795.png/
# folder_frame_006207.png/  folder_frame_015906.png/  folder_frame_025796.png/
# folder_frame_006208.png/  folder_frame_015907.png/  folder_frame_025797.png/
# folder_frame_006209.png/  folder_frame_015908.png/  folder_frame_025798.png/
# folder_frame_006210.png/  folder_frame_015909.png/  folder_frame_025799.png/
# folder_frame_006211.png/  folder_frame_015910.png/  folder_frame_025800.png/
# folder_frame_006212.png/  folder_frame_015912.png/  folder_frame_025801.png/
# folder_frame_006213.png/  folder_frame_015913.png/  folder_frame_025802.png/
# folder_frame_006214.png/  folder_frame_015914.png/  folder_frame_025803.png/
# folder_frame_006215.png/  folder_frame_015915.png/  folder_frame_025804.png/
# folder_frame_006216.png/  folder_frame_015916.png/  folder_frame_025805.png/
# folder_frame_006217.png/  folder_frame_015917.png/  folder_frame_025806.png/
# folder_frame_006218.png/  folder_frame_015918.png/  folder_frame_025807.png/
# folder_frame_006219.png/  folder_frame_015919.png/  folder_frame_025808.png/
# folder_frame_006220.png/  folder_frame_015920.png/  folder_frame_025809.png/
# folder_frame_006221.png/  folder_frame_015921.png/  folder_frame_025810.png/
# folder_frame_006222.png/  folder_frame_015922.png/  folder_frame_025811.png/
# folder_frame_006223.png/  folder_frame_015923.png/  folder_frame_025812.png/
# folder_frame_006224.png/  folder_frame_015924.png/  folder_frame_025813.png/
# folder_frame_006225.png/  folder_frame_015925.png/  folder_frame_025815.png/
# folder_frame_006226.png/  folder_frame_015926.png/  folder_frame_025816.png/
# folder_frame_006227.png/  folder_frame_015927.png/  folder_frame_025817.png/
# folder_frame_006229.png/  folder_frame_015928.png/  folder_frame_025818.png/
# folder_frame_006230.png/  folder_frame_015929.png/  folder_frame_025819.png/
# folder_frame_006231.png/  folder_frame_015930.png/  folder_frame_025820.png/
# folder_frame_006232.png/  folder_frame_015931.png/  folder_frame_025821.png/
# folder_frame_006233.png/  folder_frame_015932.png/  folder_frame_025822.png/
# folder_frame_006234.png/  folder_frame_015933.png/  folder_frame_025823.png/
# folder_frame_006235.png/  folder_frame_015934.png/  folder_frame_025824.png/
# folder_frame_006236.png/  folder_frame_015935.png/  folder_frame_025825.png/
# folder_frame_006237.png/  folder_frame_015937.png/  folder_frame_025826.png/
# folder_frame_006238.png/  folder_frame_015938.png/  folder_frame_025827.png/
# folder_frame_006239.png/  folder_frame_015939.png/  folder_frame_025828.png/
# folder_frame_006240.png/  folder_frame_015940.png/  folder_frame_025829.png/
# folder_frame_006241.png/  folder_frame_015941.png/  folder_frame_025830.png/
# folder_frame_006242.png/  folder_frame_015942.png/  folder_frame_025831.png/
# folder_frame_006243.png/  folder_frame_015943.png/  folder_frame_025832.png/
# folder_frame_006244.png/  folder_frame_015944.png/  folder_frame_025833.png/
# folder_frame_006245.png/  folder_frame_015945.png/  folder_frame_025834.png/
# folder_frame_006246.png/  folder_frame_015946.png/  folder_frame_025835.png/
# folder_frame_006247.png/  folder_frame_015947.png/  folder_frame_025836.png/
# folder_frame_006248.png/  folder_frame_015948.png/  folder_frame_025837.png/
# folder_frame_006249.png/  folder_frame_015949.png/  folder_frame_025839.png/
# folder_frame_006250.png/  folder_frame_015950.png/  folder_frame_025840.png/
# folder_frame_006251.png/  folder_frame_015951.png/  folder_frame_025841.png/
# folder_frame_006253.png/  folder_frame_015952.png/  folder_frame_025842.png/
# folder_frame_006254.png/  folder_frame_015953.png/  folder_frame_025843.png/
# folder_frame_006255.png/  folder_frame_015954.png/  folder_frame_025844.png/
# folder_frame_006256.png/  folder_frame_015955.png/  folder_frame_025845.png/
# folder_frame_006257.png/  folder_frame_015956.png/  folder_frame_025846.png/
# folder_frame_006258.png/  folder_frame_015957.png/  folder_frame_025847.png/
# folder_frame_006259.png/  folder_frame_015958.png/  folder_frame_025848.png/
# folder_frame_006260.png/  folder_frame_015959.png/  folder_frame_025849.png/
# folder_frame_006261.png/  folder_frame_015961.png/  folder_frame_025850.png/
# folder_frame_006262.png/  folder_frame_015962.png/  folder_frame_025851.png/
# folder_frame_006263.png/  folder_frame_015963.png/  folder_frame_025852.png/
# folder_frame_006264.png/  folder_frame_015964.png/  folder_frame_025853.png/
# folder_frame_006265.png/  folder_frame_015965.png/  folder_frame_025854.png/
# folder_frame_006266.png/  folder_frame_015966.png/  folder_frame_025855.png/
# folder_frame_006267.png/  folder_frame_015967.png/  folder_frame_025856.png/
# folder_frame_006268.png/  folder_frame_015968.png/  folder_frame_025857.png/
# folder_frame_006269.png/  folder_frame_015969.png/  folder_frame_025858.png/
# folder_frame_006270.png/  folder_frame_015970.png/  folder_frame_025859.png/
# folder_frame_006271.png/  folder_frame_015971.png/  folder_frame_025860.png/
# folder_frame_006272.png/  folder_frame_015972.png/  folder_frame_025861.png/
# folder_frame_006273.png/  folder_frame_015973.png/  folder_frame_025863.png/
# folder_frame_006274.png/  folder_frame_015974.png/  folder_frame_025864.png/
# folder_frame_006275.png/  folder_frame_015975.png/  folder_frame_025865.png/
# folder_frame_006277.png/  folder_frame_015976.png/  folder_frame_025866.png/
# folder_frame_006278.png/  folder_frame_015977.png/  folder_frame_025867.png/
# folder_frame_006279.png/  folder_frame_015978.png/  folder_frame_025868.png/
# folder_frame_006280.png/  folder_frame_015979.png/  folder_frame_025869.png/
# folder_frame_006281.png/  folder_frame_015980.png/  folder_frame_025870.png/
# folder_frame_006282.png/  folder_frame_015981.png/  folder_frame_025871.png/
# folder_frame_006283.png/  folder_frame_015982.png/  folder_frame_025872.png/
# folder_frame_006284.png/  folder_frame_015983.png/  folder_frame_025874.png/
# folder_frame_006285.png/  folder_frame_015984.png/  folder_frame_025879.png/
# folder_frame_006286.png/  folder_frame_015986.png/  folder_frame_025896.png/
# folder_frame_006287.png/  folder_frame_015987.png/  folder_frame_025897.png/
# folder_frame_006288.png/  folder_frame_015988.png/  folder_frame_025898.png/
# folder_frame_006289.png/  folder_frame_015989.png/  folder_frame_025899.png/
# folder_frame_006290.png/  folder_frame_015990.png/  folder_frame_025900.png/
# folder_frame_006291.png/  folder_frame_015991.png/  folder_frame_025901.png/
# folder_frame_006292.png/  folder_frame_015992.png/  folder_frame_025902.png/
# folder_frame_006293.png/  folder_frame_015993.png/  folder_frame_025903.png/
# folder_frame_006294.png/  folder_frame_015994.png/  folder_frame_025904.png/
# folder_frame_006295.png/  folder_frame_015995.png/  folder_frame_025905.png/
# folder_frame_006296.png/  folder_frame_015996.png/  folder_frame_025906.png/
# folder_frame_006297.png/  folder_frame_015997.png/  folder_frame_025907.png/
# folder_frame_006298.png/  folder_frame_015998.png/  folder_frame_025908.png/
# folder_frame_006299.png/  folder_frame_015999.png/  folder_frame_025909.png/
# folder_frame_006300.png/  folder_frame_016000.png/  folder_frame_025910.png/
# folder_frame_006302.png/  folder_frame_016001.png/  folder_frame_025912.png/
# folder_frame_006303.png/  folder_frame_016002.png/  folder_frame_025913.png/
# folder_frame_006304.png/  folder_frame_016003.png/  folder_frame_025914.png/
# folder_frame_006305.png/  folder_frame_016004.png/  folder_frame_025915.png/
# folder_frame_006306.png/  folder_frame_016005.png/  folder_frame_025916.png/
# folder_frame_006307.png/  folder_frame_016006.png/  folder_frame_025917.png/
# folder_frame_006308.png/  folder_frame_016007.png/  folder_frame_025918.png/
# folder_frame_006309.png/  folder_frame_016008.png/  folder_frame_025919.png/
# folder_frame_006310.png/  folder_frame_016010.png/  folder_frame_025920.png/
# folder_frame_006311.png/  folder_frame_016011.png/  folder_frame_025921.png/
# folder_frame_006312.png/  folder_frame_016012.png/  folder_frame_025922.png/
# folder_frame_006313.png/  folder_frame_016013.png/  folder_frame_025923.png/
# folder_frame_006314.png/  folder_frame_016014.png/  folder_frame_025924.png/
# folder_frame_006315.png/  folder_frame_016015.png/  folder_frame_025925.png/
# folder_frame_006316.png/  folder_frame_016016.png/  folder_frame_025926.png/
# folder_frame_006329.png/  folder_frame_016017.png/  folder_frame_025927.png/
# folder_frame_006349.png/  folder_frame_016018.png/  folder_frame_025928.png/
# folder_frame_006353.png/  folder_frame_016019.png/  folder_frame_025929.png/
# folder_frame_006358.png/  folder_frame_016020.png/  folder_frame_025930.png/
# folder_frame_006362.png/  folder_frame_016021.png/  folder_frame_025931.png/
# folder_frame_006375.png/  folder_frame_016022.png/  folder_frame_025932.png/
# folder_frame_006378.png/  folder_frame_016023.png/  folder_frame_025933.png/
# folder_frame_006381.png/  folder_frame_016024.png/  folder_frame_025934.png/
# folder_frame_006398.png/  folder_frame_016025.png/  folder_frame_025935.png/
# folder_frame_006400.png/  folder_frame_016026.png/  folder_frame_025937.png/
# folder_frame_006401.png/  folder_frame_016027.png/  folder_frame_025938.png/
# folder_frame_006402.png/  folder_frame_016028.png/  folder_frame_025939.png/
# folder_frame_006403.png/  folder_frame_016029.png/  folder_frame_025940.png/
# folder_frame_006404.png/  folder_frame_016030.png/  folder_frame_025941.png/
# folder_frame_006405.png/  folder_frame_016031.png/  folder_frame_025942.png/
# folder_frame_006406.png/  folder_frame_016032.png/  folder_frame_025943.png/
# folder_frame_006407.png/  folder_frame_016034.png/  folder_frame_025944.png/
# folder_frame_006408.png/  folder_frame_016035.png/  folder_frame_025945.png/
# folder_frame_006409.png/  folder_frame_016036.png/  folder_frame_025946.png/
# folder_frame_006410.png/  folder_frame_016037.png/  folder_frame_025947.png/

# %%
# %cd ../
# Out:
# /home/ubuntu/11785_SceneDetection_Quantization

# %%
# %pwd
# Out:
# '/home/ubuntu/11785_SceneDetection_Quantization'

# %%
# %mkdir unique-142p-valid-backup
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'

# %%
# create reference index
ref_image_folder_indices = os.listdir()
ref_image_folder_indices.sort()
print(ref_image_folder_indices[:10])
# Out:
# ['folder_frame_000001.png', 'folder_frame_000012.png', 'folder_frame_000015.png', 'folder_frame_000016.png', 'folder_frame_000017.png', 'folder_frame_000018.png', 'folder_frame_000020.png', 'folder_frame_000021.png', 'folder_frame_000022.png', 'folder_frame_000023.png']

# %% [markdown]
# ### DataLoader

# %%
def load_data(phase, data_dir):
    transform_list = data_transforms(phase)
    if phase == "train":
        dataset = datasets.ImageFolder(data_dir, transform=transform_list)
        data_loader = torch.utils.data.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True, num_workers=NUM_WORKERS)
    else:
        dataset = datasets.ImageFolder(data_dir, transform=transform_list)
        data_loader = torch.utils.data.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False, drop_last=True, num_workers=NUM_WORKERS)
    return dataset, data_loader
        
def data_transforms(phase):
    if phase == "train":
        transform = transforms.Compose([transforms.Resize((IMG_SIZE, IMG_SIZE)),
                                        transforms.RandomHorizontalFlip(p=0.5),
                                        transforms.ColorJitter(brightness=0.8, contrast=0.8, saturation=0.8),
                                        transforms.ToTensor()])
    else:
        transform = transforms.Compose([transforms.Resize((IMG_SIZE, IMG_SIZE)),
                                        transforms.ToTensor()])
    return transform

# %%
# create validation dataloader
valid_dataset, valid_dataloader = load_data(phase="eval", data_dir=new_data_dir)
example_valid_input = next(iter(valid_dataloader))[0]
print("\nDetails of the validation dataset and data loader are below.\n")
print("Num Observations: {}\nNum Batches:\t  {}\nBatch Shape:\t  {}\nNum Classes:\t  {}".\
      format(len(valid_dataset), len(valid_dataloader), list(example_valid_input.shape), len(valid_dataset.classes)))
print("True Observations used: ", BATCH_SIZE * len(valid_dataloader))
# Out:
# Details of the validation dataset and data loader are below.
#
# Num Observations: 14196
# Num Batches:	  221
# Batch Shape:	  [64, 3, 64, 64]
# Num Classes:	  14196
# True Observations used:  14144

# %%
# create dictionary for matching
batch_idx = [i for i in range(BATCH_SIZE * len(valid_dataloader))]
batch_to_image = dict(zip(batch_idx, ref_image_folder_indices))

# %% [markdown]
# ### Convert Pytorch model to ONNX model

# %%
# model path
onnx_model_file = "./onnx_model/"

# %%
if not os.path.exists(onnx_model_file):
    os.mkdir(onnx_model_file)

# %%
# convert pytorch model to ONNX model
onnx_model_path = onnx_model_file + model_name + ".onnx"     # float 32
qi_onnx_model_path = onnx_model_file + "QI-" + model_name + ".onnx"  # int 8
print(onnx_model_path)
print(qi_onnx_model_path)
# Out:
# ./onnx_model/Model_baseline.onnx
# ./onnx_model/QI-Model_baseline.onnx

# %%
# input to the model (same shape as batch input shape), just put some random input in
x = torch.ones(64, 3, 64, 64)
# Export pytorch model as onnx model
torch.onnx.export(model, x, onnx_model_path, input_names=["input"], output_names=["output"], opset_version=11)

# %%
#!pip install --upgrade onnx

# %%
# load onnx model
onnx_model = onnx.load(onnx_model_path)
onnx.checker.check_model(onnx_model)

# %% [markdown]
# ### Quantize Float32 Model to Int8 Model

# %%
# per channel=True???
kwargs = {"op_types_to_quantize":     [],
          "per_channel":              True,
          "reduce_range":             False,
          "activation_type":          onnxruntime.quantization.QuantType.QUInt8,
          "weight_type":              onnxruntime.quantization.QuantType.QUInt8,
          "nodes_to_quantize":        [],
          "nodes_to_exclude":         [],
          "use_external_data_format": False}

onnxruntime.quantization.quantize_dynamic(onnx_model_path, qi_onnx_model_path, **kwargs)

# %%
# Compare model parameters size
onnx_size_mb   = os.path.getsize(onnx_model_path)/1e6
qi_onnx_size_mb = os.path.getsize(qi_onnx_model_path)/1e6

print("\nONNX model size (MB):     {:.2f}".format(onnx_size_mb))
print("\nQI-ONNX model size (MB):  {:.2f}".format(qi_onnx_size_mb))
# Out:
# ONNX model size (MB):     12.84
#
# QI-ONNX model size (MB):  7.96

# %% [markdown]
# ### Perform Inference on Input Images

# %%
class init_inference:
    def __init__(self, session):
        self.session = session
        
    def __call__(self, image):
        input_data = image.numpy()
        input_name  = self.session.get_inputs()[0].name
    
        return self.session.run(None, {input_name: input_data})

def mean_latency_fn(tqdm_dataloader):
    start = tqdm_dataloader.start_t
    stop = tqdm_dataloader.last_print_t
    n = tqdm_dataloader.n
    mean_latency = (stop - start)/n
    return mean_latency

def simple_table(data_multilist, x_label_list, y_label_list):
    for i in range(len(y_label_list)+1):
        if i == 0:
            row = ["\t"]
            row.extend(x_label_list)
            string = "\t".join(row)
        else:
            row = [y_label_list[i-1]]
            
            row.extend([format(x, ".6f") for x in data_multilist[i-1]])
            string = "\t".join(row)
            
        print(string)
        
    return None

def plot_statistic(x, y, title, x_label, y_label):

    label_pos = [i for i, _ in enumerate(x)]

    plt.figure(figsize=(12, 6))
    plt.bar(label_pos, x, color='black', width=0.8)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.xticks(label_pos, y)
    
    plt.show()
    
    return None

def valid_model(valid_dataloader, session):
    tqdm_dataloader = tqdm(valid_dataloader)
    inference = init_inference(session)
    valid_loss = {'val_total_loss':0.0, 'val_recon_loss':0.0,'val_kld':0.0}
    len_data_loader = len(valid_dataloader)
    
    # Latent Space
    mu = None
    logvar = None
    
    # origin_images
    origin_images_list = []
    index_list = []
    
    for _, (images, y) in enumerate(tqdm_dataloader):
        results = inference(images)
        # covert results into tensor
        results_converted = []
        for result in results:
            result = torch.tensor(result)
            results_converted.append(result)
        
        # Latent Space
        latent_u = results_converted[2]
        latent_logvar = results_converted[3]
        
        loss = model.loss_function(*results_converted,M_N = 1.0/float(len_data_loader), batch_size=BATCH_SIZE)
        
        valid_loss['val_total_loss'] += loss['total_loss'].cpu().detach().numpy()
        valid_loss['val_recon_loss'] += loss['recon_loss'].cpu().detach().numpy()
        valid_loss['val_kld'] += loss['kld'].cpu().detach().numpy()
        
        # Latent Space
        if mu == None and logvar == None:
            mu = latent_u
            logvar = latent_logvar
        else:
            mu = torch.cat((mu, latent_u))
            logvar = torch.cat((logvar, latent_logvar))
            
        # origin_images
        origin_images_list.append(images)
        index_list.append(y)
            
    valid_loss['val_total_loss'] /= len_data_loader
    valid_loss['val_recon_loss'] /= len_data_loader
    valid_loss['val_kld'] /= len_data_loader
    mean_latency = mean_latency_fn(tqdm_dataloader)

    origin_images_tensor = torch.cat(origin_images_list, dim=0)
    index_tensor = torch.cat(index_list, dim=0)
    
    return valid_loss, mean_latency, origin_images_tensor, index_tensor, mu.cpu().detach().numpy(), logvar.cpu().detach().numpy()

# %%
ort_session = onnxruntime.InferenceSession(onnx_model_path)
loss, mean_latency, origin_images_tensor, index_tensor, mu, logvar = valid_model(valid_dataloader, ort_session)
# Out:
#   0%|          | 0/221 [00:00<?, ?it/s]

# %%
print("Basline Model Loss (Float 32): ")
print(loss)
# Out:
# Basline Model Loss (Float 32):
# {'val_total_loss': 185.88345619132616, 'val_recon_loss': 140.68147370178775, 'val_kld': 22.6009912318234}

# %%
print(mean_latency)
# Out:
# 0.22942406667303716

# %%
qi_ort_session = onnxruntime.InferenceSession(qi_onnx_model_path)
qi_loss, qi_mean_latency, qi_origin_images_tensor, qi_index_tensor, qi_mu, qi_logvar = valid_model(valid_dataloader, qi_ort_session)
# Out:
#   0%|          | 0/221 [00:00<?, ?it/s]

# %%
print("Quantized Basline Model Loss (Int 8): ")
print(qi_loss)
# Out:
# Quantized Basline Model Loss (Int 8):
# {'val_total_loss': 187.2001666763789, 'val_recon_loss': 141.90202206400184, 'val_kld': 22.649072112001445}

# %%
print(qi_mean_latency)
# Out:
# 0.26821120939643134

# %%
print(qi_mean_latency - mean_latency)
# Out:
# 0.038787142723394175

# %% [markdown]
# ### Compare Accuracy of the scene change (Float 32 vs Int 8)

# %%
def KL_latent(mu1, logvar1, mu2, logvar2):
    latent_dim = mu1.shape[0]
    sigma1 = np.exp(0.5*logvar1)
    sigma2 = np.exp(0.5*logvar2)
    KL = 0.5*((sigma1 / sigma2).sum() + ((mu2 - mu1) * (mu2 - mu1) / sigma2).sum() - latent_dim + np.log(sigma2.prod() / sigma1.prod()))
    return KL

# %%
def compute_frame_KL_div(mu, logvar):
    """
    mu: 
    logvar:
    return: 
    """
    assert mu.shape[0] == logvar.shape[0]
    kl_div_list = []
    n = mu.shape[0]
    # O(N) complexity
    for i in range(1, n):
        kl_div = KL_latent(mu[i-1], logvar[i-1], mu[i], logvar[i])
        kl_div_list.append(kl_div)
    return np.array(kl_div_list)

# %%
def topK_KLdiv_search(kl_div_list, K=259):
    """
    kl_div_list:
    return: 
    """
    assert K >= 259
    assert len(kl_div_list) > K
    scene_change_pairs = []
    Kmax_index = kl_div_list.argsort()[-K:][::-1]
    for pair in zip(Kmax_index, Kmax_index + 1):
        scene_change_pairs.append(pair)
    return scene_change_pairs

# %%
def pair2image(scene_change_pairs, batch_to_image):
    """
    scene_change_pairs:
    batch_to_image: dict
    return:
    """
    scene_change_list = []
    for pair in scene_change_pairs:
        frame1 = batch_to_image[pair[0]]
        frame2 = batch_to_image[pair[1]]
        scene_change_list.append((frame1[7:], frame2[7:]))
    return scene_change_list

# %%
# compare predict dataframe with label dataframe
def scene_change_detect_accuracy(scene_change_labels, predict_scene_change_df):
    count = 0
    total = len(scene_change_labels)
    for i in range(len(scene_change_labels)):
        pred_frame1 = predict_scene_change_df.iloc[i]['frame1']
        pred_frame2 = predict_scene_change_df.iloc[i]['frame2']
        true_frame1_series = scene_change_labels['frame1']
        if pred_frame1 in true_frame1_series.values:
            # find corresponding index of this predict frame1 in the groud_truth df
            idx = true_frame1_series[true_frame1_series == pred_frame1].index[0]
            # compare pred_frame2 and groud truth frame2 is the same
            true_frame2 = scene_change_labels.iloc[idx]['frame2']
            if pred_frame2 == true_frame2:
                count += 1
    acc = count / total
    return acc, count

# %%
# read scene-change.csv
scene_change_labels = pd.read_csv("scene-change.csv")

# %% [markdown]
# **Float 32 Model**

# %%
# compute kl_divergence
kl_div_list = compute_frame_KL_div(mu, logvar)
scene_change_pairs = topK_KLdiv_search(kl_div_list)
scene_change_pairs_imagename = pair2image(scene_change_pairs, batch_to_image)

# %%
# Create Dataframe
predict_scene_change_df = pd.DataFrame(scene_change_pairs_imagename, columns=["frame1", "frame2"])
predict_scene_change_df = predict_scene_change_df.sort_values(by=['frame1']).reset_index(drop=True)

# %%
# Compute Scene change accuracy
acc, count = scene_change_detect_accuracy(scene_change_labels, predict_scene_change_df)
print("Accuracy of Float-32 Model is: {:,.2f}%".format(acc*100))
print("Correctly Identified Scene-Change: ",count)
# Out:
# Accuracy of Float-32 Model is: 84.17%
# Correctly Identified Scene-Change:  218

# %% [markdown]
# **Int 8 Model**

# %%
# compute kl_divergence
qi_kl_div_list = compute_frame_KL_div(qi_mu, qi_logvar)
qi_scene_change_pairs = topK_KLdiv_search(qi_kl_div_list)
qi_scene_change_pairs_imagename = pair2image(qi_scene_change_pairs, batch_to_image)

# %%
# Create Dataframe
qi_predict_scene_change_df = pd.DataFrame(qi_scene_change_pairs_imagename, columns=["frame1", "frame2"])
qi_predict_scene_change_df = qi_predict_scene_change_df.sort_values(by=['frame1']).reset_index(drop=True)

# %%
# Compute Scene change accuracy
qi_acc, qi_count = scene_change_detect_accuracy(scene_change_labels, qi_predict_scene_change_df)
print("Accuracy of Int-8 Model is: {:,.2f}%".format(qi_acc*100))
print("Correctly Identified Scene-Change: ",qi_count)
# Out:
# Accuracy of Int-8 Model is: 84.94%
# Correctly Identified Scene-Change:  220

# %% [markdown]
# ### Visualize Predict Scene-Change and Non-Scene Change Images (5 each)
#
# Also, what are some of the scene changes that Int-8 model captures but float-32 model doesn't?

# %%
def plot_images(images_tensor):
    """
    images_tensor: tensor of images -> shape(B, C, H, W)
    return: plot of images
    """
    plt.figure(figsize=(8,8))
    plt.axis("off")
    plt.imshow(np.transpose(vutils.make_grid(images_tensor, padding=2, normalize=True).cpu(),(1,2,0)))
    plt.show()

# %% [markdown]
# **Float 32 Model**

# %% [markdown]
# **Int 8 Model**
